# %% [markdown]
# [この記事][1]を参照してノートブックを作った
#
#
# [1]:https://www.kaggle.com/thebrownviking20/everything-you-can-do-with-a-time-series

# %% [markdown]
# # 1.Introduction to date and time

# %%
# Importing libraries
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
# Above is a special style template for matplotlib, highly useful for visualizing time series data
# %matplotlib inline
from pylab import rcParams
from plotly import tools
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import statsmodels.api as sm
from numpy.random import normal, seed
from scipy.stats import norm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
import math
from sklearn.metrics import mean_squared_error

for _ in os.listdir("./input"):
    print(_)
    for f in os.listdir("./input/%s"%_):
        print("└",f)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# stock_time_series
# └ GOOGL_2006-01-01_to_2018-01-01.csv
# └ MSFT_2006-01-01_to_2018-01-01.csv
# weather_time_series
# └ humidity.csv
# └ pressure.csv

# %%
google = pd.read_csv('./input/stock_time_series/GOOGL_2006-01-01_to_2018-01-01.csv',index_col='Date',parse_dates=['Date'])
google.head()
# Out:
#               Open    High     Low   Close    Volume   Name
# Date
# 2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %%
humidity = pd.read_csv('./input/weather_time_series/humidity.csv',index_col='datetime',parse_dates=['datetime'])
humidity.head()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN      NaN          NaN
# 2012-10-01 13:00:00       76.0      81.0           88.0     81.0         88.0
# 2012-10-01 14:00:00       76.0      80.0           87.0     80.0         88.0
# 2012-10-01 15:00:00       76.0      80.0           86.0     80.0         88.0
# 2012-10-01 16:00:00       77.0      80.0           85.0     79.0         88.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 12:00:00        NaN        NaN      NaN          NaN     NaN  ...
# 2012-10-01 13:00:00       82.0       22.0     23.0         50.0    62.0  ...
# 2012-10-01 14:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 15:00:00       81.0       21.0     23.0         49.0    62.0  ...
# ...

# %%
humidity = humidity.iloc[1:]
humidity = humidity.fillna(method='ffill')
humidity.head()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 13:00:00       76.0      81.0           88.0     81.0         88.0
# 2012-10-01 14:00:00       76.0      80.0           87.0     80.0         88.0
# 2012-10-01 15:00:00       76.0      80.0           86.0     80.0         88.0
# 2012-10-01 16:00:00       77.0      80.0           85.0     79.0         88.0
# 2012-10-01 17:00:00       78.0      79.0           84.0     79.0         88.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 13:00:00       82.0       22.0     23.0         50.0    62.0  ...
# 2012-10-01 14:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 15:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 16:00:00       81.0       21.0     23.0         49.0    62.0  ...
# ...

# %%
humidity["Kansas City"].asfreq('M').plot()
# asfreq metod is used to convert a time series to a specified frequency. Here it is monhly frequency.
plt.title('Humidity in Kansas City over time(Monthly frequency)')
plt.show()

# %%
google['2008':'2010'].plot(subplots=True, figsize=(10,12))
plt.title('Google stock attributes from 2008 to 2010')
plt.savefig('stocks_google.png')
plt.show()

# %%
# Creating a Timestamp
timestamp = pd.Timestamp(2017,1,1,12)
print(timestamp,"\n")

# Creating a period
period = pd.Period("2017-01-01","S")
print(period,"\n")

# Checking if the given timestamp exists in the given period
print(period.start_time < timestamp < period.end_time,"\n")

# Converting timestamp to period
new_period = timestamp.to_period(freq='H')
print(new_period,"\n")

# Converting period to timestamp
new_timestamp = period.to_timestamp(freq='H', how='start')
print(new_timestamp)
# Out:
# 2017-01-01 12:00:00
#
# 2017-01-01 00:00:00
#
# False
#
# 2017-01-01 12:00
#
# 2017-01-01 00:00:00

# %%
# Creating a datetimeindex with daily frequency
dr1 = pd.date_range(start='2018-09-01', end='2018-09-09')
print(dr1,"\n")

# Creating a datetimeindex with monthly frequency
dr2 = pd.date_range(start='1/1/18', end='1/1/19', freq='M')
print(dr2,"\n")

# Creating a datetime index without specifying start date and using periods
dr3 = pd.date_range(end='1/4/2014', periods=8, freq='min')
print(dr3,"\n")

# Creating a datetimeindex specifying start date, end date and period
dr4 = pd.date_range(start='2013-04-24', end='2014-11-27', freq='w-wed')
print(dr4,"\n")
# Out:
# DatetimeIndex(['2018-09-01', '2018-09-02', '2018-09-03', '2018-09-04',
#                '2018-09-05', '2018-09-06', '2018-09-07', '2018-09-08',
#                '2018-09-09'],
#               dtype='datetime64[ns]', freq='D')
#
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31',
#                '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='M')
#
# DatetimeIndex(['2014-01-03 23:53:00', '2014-01-03 23:54:00',
#                '2014-01-03 23:55:00', '2014-01-03 23:56:00',
#                '2014-01-03 23:57:00', '2014-01-03 23:58:00',
#                '2014-01-03 23:59:00', '2014-01-04 00:00:00'],
#               dtype='datetime64[ns]', freq='T')
#
# DatetimeIndex(['2013-04-24', '2013-05-01', '2013-05-08', '2013-05-15',
#                '2013-05-22', '2013-05-29', '2013-06-05', '2013-06-12',
# ...

# %%
df = pd.DataFrame({'year':[2015,2016], 'month':[2,3], 'day':[4,5]})
print(df,"\n")

df = pd.to_datetime(df)
print(df,"\n")

df = pd.to_datetime('01-01-2017')
print(df)
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5
#
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]
#
# 2017-01-01 00:00:00

# %%
humidity["Vancouver"].asfreq('M').plot(legend=True)
shifted = humidity["Vancouver"].asfreq('M').shift(6).plot(legend=True)
shifted.legend(['Vancouver','Vancouver_lagged'])
plt.show()

# %% [markdown]
# <hr>
# <b>Upsampling</b> - Time series is resampled from low frequency to high frequency(Monthly to daily frequency). It involves filling or interpolating missing data.
# <b>Downsampling</b> - Time series is resampled from high frequency to low frequency(Weekly to monthly). It involves aggregation of existing data.

# %%
# Let's use pressure data to demonstrate this
pressure = pd.read_csv('./input/weather_time_series/pressure.csv', index_col='datetime', parse_dates=['datetime'])
pressure.tail()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00        NaN    1031.0            NaN   1030.0       1016.0
# 2017-11-29 21:00:00        NaN    1030.0            NaN   1030.0       1016.0
# 2017-11-29 22:00:00        NaN    1030.0            NaN   1029.0       1015.0
# 2017-11-29 23:00:00        NaN    1029.0            NaN   1028.0       1016.0
# 2017-11-30 00:00:00        NaN    1029.0            NaN   1028.0       1015.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00     1017.0     1021.0   1018.0       1025.0  1016.0  ...
# 2017-11-29 21:00:00     1017.0     1020.0   1018.0       1024.0  1018.0  ...
# 2017-11-29 22:00:00     1016.0     1020.0   1017.0       1024.0  1018.0  ...
# 2017-11-29 23:00:00     1016.0     1020.0   1016.0       1024.0  1020.0  ...
# ...

# %%
# Sigh! A lot of cleaning is required.
pressure = pressure.iloc[1:]
pressure = pressure.fillna(method='ffill')
pressure.tail()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00     1021.0    1031.0         1013.0   1030.0       1016.0
# 2017-11-29 21:00:00     1021.0    1030.0         1013.0   1030.0       1016.0
# 2017-11-29 22:00:00     1021.0    1030.0         1013.0   1029.0       1015.0
# 2017-11-29 23:00:00     1021.0    1029.0         1013.0   1028.0       1016.0
# 2017-11-30 00:00:00     1021.0    1029.0         1013.0   1028.0       1015.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00     1017.0     1021.0   1018.0       1025.0  1016.0  ...
# 2017-11-29 21:00:00     1017.0     1020.0   1018.0       1024.0  1018.0  ...
# 2017-11-29 22:00:00     1016.0     1020.0   1017.0       1024.0  1018.0  ...
# 2017-11-29 23:00:00     1016.0     1020.0   1016.0       1024.0  1020.0  ...
# ...

# %%
pressure = pressure.fillna(method='bfill')
pressure.head()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 13:00:00      807.0    1024.0         1009.0   1027.0       1013.0
# 2012-10-01 14:00:00      807.0    1024.0         1009.0   1027.0       1013.0
# 2012-10-01 15:00:00      807.0    1024.0         1009.0   1028.0       1013.0
# 2012-10-01 16:00:00      807.0    1024.0         1009.0   1028.0       1013.0
# 2012-10-01 17:00:00      807.0    1024.0         1009.0   1029.0       1013.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 13:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# 2012-10-01 14:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# 2012-10-01 15:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# 2012-10-01 16:00:00     1013.0     1018.0   1013.0       1024.0  1028.0  ...
# ...

# %%
# Shape before resampling(downsampling)
print(pressure.shape)

# We downsample from hourly to 3 day frequency aggregated using mean
pressure = pressure.resample('3D').mean()

pressure.head()
# Out:
# (45252, 36)
#               Vancouver     Portland  San Francisco      Seattle  Los Angeles  \
# datetime
# 2012-10-01   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-04  1019.083333  1023.041667    1014.694444  1028.305556  1015.555556
# 2012-10-07  1013.930556  1017.444444    1016.597222  1018.736111  1013.416667
# 2012-10-10  1015.000000  1015.430556    1014.833333  1018.416667  1010.694444
# 2012-10-13  1008.152778  1018.111111    1021.069444  1015.930556  1017.277778
#
#               San Diego    Las Vegas      Phoenix  Albuquerque       Denver  \
# datetime
# 2012-10-01  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-04  1016.277778  1013.194444  1014.097222  1019.972222  1020.666667
# 2012-10-07  1014.222222  1012.888889  1011.861111  1005.833333  1020.458333
# 2012-10-10  1014.013889  1000.166667  1005.611111   986.000000   984.486111
# 2012-10-13  1018.375000  1015.666667  1015.500000  1013.625000  1010.444444
#
# ...

# %%
# shape after resampling(downsampling)
print(pressure.shape)

# Much less rows are left. Now, we will upsample from 3 day frequency to daily frequency
pressure = pressure.resample('D').pad()
pressure.head()
# Out:
# (629, 36)
#               Vancouver     Portland  San Francisco      Seattle  Los Angeles  \
# datetime
# 2012-10-01   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-02   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-03   931.627119  1022.644068    1010.881356  1031.271186  1011.627119
# 2012-10-04  1019.083333  1023.041667    1014.694444  1028.305556  1015.555556
# 2012-10-05  1019.083333  1023.041667    1014.694444  1028.305556  1015.555556
#
#               San Diego    Las Vegas      Phoenix  Albuquerque       Denver  \
# datetime
# 2012-10-01  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-02  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-03  1011.966102  1016.322034  1012.084746  1022.542373  1024.118644
# 2012-10-04  1016.277778  1013.194444  1014.097222  1019.972222  1020.666667
# 2012-10-05  1016.277778  1013.194444  1014.097222  1019.972222  1020.666667
#
# ...

# %%
# Shape after resampling(upsampling)
pressure.shape
# Out:
# (1885, 36)

# %% [markdown]
# # 2.Finance and statistics

# %%
# Percent change
google["Change"] = google.High.div(google.High.shift())
google["Change"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Stock returns
google["Return"] = google.Change.sub(1).mul(100)
google["Return"].plot(figsize=(20,8))
plt.show()

# Another way to calculate returns
google.High.pct_change().mul(100).plot(figsize=(20,8))
plt.show()

# %%
# Absolute change in successive rows
google.High.diff().plot(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Comparing two or more time series
# We choose microsoft stocks to compare them with google
microsoft = pd.read_csv("./input/stock_time_series/MSFT_2006-01-01_to_2018-01-01.csv",index_col='Date',parse_dates=['Date'])

# Plotting before normalization
google.High.plot()
microsoft.High.plot()
plt.legend(["Google","Microsoft"])
plt.show()

# Normalizing and comparison
# Both stock start from 100
normalized_google = google.High.div(google.High.iloc[0]).mul(100)
normalized_microsoft = microsoft.High.div(microsoft.High.iloc[0]).mul(100)
normalized_google.plot()
normalized_microsoft.plot()
plt.legend(['Google','Microsoft'])
plt.show()

# %%
# Window functions
# Window functions are used to identify sub periods, calculates sub-metrics of sub-periods.
# Rolling - Same size and sliding
# Expanding - Contrains all prior values

# Rolling window functions
rolling_google = google.High.rolling('90D').mean()
google.High.plot()
rolling_google.plot()
plt.legend(['High','Rolling Mean'])
# Plotting a rolling mean of 90 days window original High attribute of google stocks
plt.show()

# Expanding window functions
microsoft_mean = microsoft.High.expanding().mean()
microsoft_std = microsoft.High.expanding().std()
microsoft.High.plot()
microsoft_mean.plot()
microsoft_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.show()

# %%
# OHLC charts
# OHLC chart of June 2008
trace = go.Ohlc(x=google['06-2008'].index,
                open=google['06-2008'].Open,
                high=google['06-2008'].High,
                low=google['06-2008'].Low,
                close=google['06-2008'].Close)
data = [trace]
iplot(data, filename='simple_ohlc')
# Out:
# <div>                            <div id="057053e9-5e6c-4175-ba1c-38f6c5def207" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("057053e9-5e6c-4175-ba1c-38f6c5def207")) {                    Plotly.newPlot(                        "057053e9-5e6c-4175-ba1c-38f6c5def207",                        [{"close":[287.79,283.93,286.4,293.44,283.78,279.21,277.36,272.87,276.75,286.04,286.69,285.01,281.47,280.38,273.49,272.88,271.42,275.78,264.67,264.3,263.47],"high":[292.24,290.54,289.29,294.31,290.65,285.28,279.69,278.95,279.28,288.14,289.84,289.32,284.78,282.17,278.77,276.85,275.87,279.18,272.74,265.26,269.27],"low":[285.92,280.59,282.56,288.39,283.78,272.97,273.66,272.5,273.71,280.95,283.53,284.47,279.86,275.68,272.53,271.28,267.82,272.11,264.39,257.8,261.79],"o
# ...

# %%
# OHLC chart of 2008
trace = go.Ohlc(x=google['2008'].index,
                open=google['2008'].Open,
                high=google['2008'].High,
                low=google['2008'].Low,
                close=google['2008'].Close)
data = [trace]
iplot(data, filename='simple_ohlc')
# Out:
# <div>                            <div id="b2901f98-0a8d-4c01-90ab-49afb6e7e1e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2901f98-0a8d-4c01-90ab-49afb6e7e1e2")) {                    Plotly.newPlot(                        "b2901f98-0a8d-4c01-90ab-49afb6e7e1e2",                        [{"close":[342.94,343.01,328.83,324.95,316.16,326.93,323.69,319.44,327.24,319.14,308.28,300.7,300.43,292.47,274.58,287.53,283.48,278.27,275.54,274.41,282.43,258.21,247.96,253.65,251.11,252.73,258.6,260.84,259.3,267.58,266.39,265.08,254.73,254.75,251.68,254.15,243.46,232.33,236.67,237.93,235.83,228.74,222.52,224.07,216.57,216.89,207.02,220.14,220.31,221.73,219.18,210.14,219.8,216.22,216.99,230.51,225.62,229.32,222.26,219.26,220.46,233.09,233.08,227.79,235.78,238.65
# ...

# %%
# Candlestick charts
# Candlestick chart of march 2008
trace = go.Candlestick(x=google['03-2008'].index,
                       open=google['03-2008'].Open,
                       high=google['03-2008'].High,
                       low=google['03-2008'].Low,
                       close=google['03-2008'].Close)
data = [trace]
iplot(data, filename='simple_candlestick')
# Out:
# <div>                            <div id="6dcc194b-247e-4225-b106-e1b3bdf745b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dcc194b-247e-4225-b106-e1b3bdf745b5")) {                    Plotly.newPlot(                        "6dcc194b-247e-4225-b106-e1b3bdf745b5",                        [{"close":[228.74,222.52,224.07,216.57,216.89,207.02,220.14,220.31,221.73,219.18,210.14,219.8,216.22,216.99,230.51,225.62,229.32,222.26,219.26,220.46],"high":[236.6,226.91,227.31,226.88,220.22,215.72,220.3,224.16,223.71,224.89,217.07,220.64,223.97,218.07,233.12,228.96,231.67,224.53,227.01,221.57],"low":[225.28,218.11,222.22,215.81,213.33,206.73,212.54,219.25,214.6,215.53,206.26,212.98,216.05,208.96,219.08,223.22,224.87,220.47,217.37,216.22],"open":[235.99,225.7,22
# ...

# %%
# Candlestick chart of 2006-2018
trace = go.Candlestick(x=google.index,
                       open=google.Open,
                       high=google.High,
                       low=google.Low,
                       close=google.Close)
data = [trace]
iplot(data,filename="simple_candlestick")
# Out:
# <div>                            <div id="559cee83-60e4-433b-b183-51c7a56f70cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("559cee83-60e4-433b-b183-51c7a56f70cb")) {                    Plotly.newPlot(                        "559cee83-60e4-433b-b183-51c7a56f70cb",                        [{"close":[217.83,222.84,225.85,233.06,233.68,235.11,236.05,232.05,233.36,233.79,222.68,218.44,199.93,213.96,221.74,216.72,217.35,216.96,213.62,216.55,201.09,198.22,190.97,192.74,184.14,184.72,179.56,181.49,173.02,171.83,171.36,183.41,184.56,183.48,182.93,189.22,188.89,195.38,181.49,182.58,188.41,189.28,184.23,182.41,177.12,171.67,168.92,168.7,175.76,172.42,169.55,170.06,174.27,170.13,170.28,171.12,183.08,185.03,188.79,197.69,194.41,195.19,195.04,202.37,204.2,205.
# ...
